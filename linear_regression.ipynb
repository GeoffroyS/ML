# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_boston
import pprint

# %%
boston_ds = load_boston()
boston_df = pd.DataFrame(boston_ds.data,
                         columns = boston_ds.feature_names)
boston_df['target'] = boston_ds.target
print(boston_df.shape)
print(boston_df.head())
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
# exploratory analysis
sns.set(rc = {'figure.figsize': (11.7, 8.27)})
sns.distplot(boston_df['target'], bins = 50)
plt.show()

print(boston_df.describe())

# missing values?
pd.isnull(boston_df).sum()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# check for correlated features
corr_matrix = boston_df.corr(method='pearson')

mask = np.zeros_like(corr_matrix,
                     dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# colormap
cmap = sns.diverging_palette(220,
                             10,
                             as_cmap = True)
sns.heatmap(corr_matrix,
            mask = mask,
            cmap = cmap,
            annot = True)

# %%
# check what colum is correlated with the target
# use absolute values since we're also interested in negative correlation
pearson = boston_df.corr(method='pearson')
corr_with_target = pearson.loc['target'][:-1]

# using extended slice ( [::] ) with -1 as the third argument (the step)
# to return a copy with every argument (1) in reverse order
print(corr_with_target[abs(corr_with_target).argsort()[::-1]])

# significant correlations excluding the target
threshold = 0.5
attributes = pearson.iloc[:-1,:-1]
#(attributes[abs(attributes) > threshold][attributes != 1.0]).unstack().dropna().to_dict()
#().unstack().dropna().to_dict()
sign_corr = attributes[abs(attributes)>threshold][abs(attributes) != 1]
sign_corr_dict = (sign_corr.unstack()
                           .dropna()
                           .to_dict())
pprint.pprint(sign_corr_dict)
# Out:
# LSTAT     -0.737663
# RM         0.695360
# PTRATIO   -0.507787
# INDUS     -0.483725
# TAX       -0.468536
# NOX       -0.427321
# CRIM      -0.388305
# RAD       -0.381626
# AGE       -0.376955
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# Name: target, dtype: float64
# {('AGE', 'DIS'): -0.7478805408686316,
#  ('AGE', 'INDUS'): 0.644778511355255,
#  ('AGE', 'LSTAT'): 0.6023385287262399,
#  ('AGE', 'NOX'): 0.7314701037859579,
#  ('AGE', 'TAX'): 0.506455593550705,
#  ('AGE', 'ZN'): -0.5695373420992127,
#  ('CRIM', 'RAD'): 0.6255051452626011,
#  ('CRIM', 'TAX'): 0.5827643120325845,
#  ('DIS', 'AGE'): -0.7478805408686316,
#  ('DIS', 'INDUS'): -0.7080269887427683,
#  ('DIS', 'NOX'): -0.7692301132258261,
#  ('DIS', 'TAX'): -0.5344315844084561,
#  ('DIS', 'ZN'): 0.6644082227621132,
#  ('INDUS', 'AGE'): 0.644778511355255,
#  ('INDUS', 'DIS'): -0.7080269887427683,
#  ('INDUS', 'LSTAT'): 0.6037997164766213,
#  ('INDUS', 'NOX'): 0.7636514469209145,
# ...
